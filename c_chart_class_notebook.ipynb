# %%
from control_chart_class import ControlChart
import pandas as pd

# %%
dog_data_df =  pd.read_excel('dog_treats_data.xlsx')
dog_data_df.head()
# Out:
#    sample_no   x1   x2   x3   x4   x5    x6    x7
# 0          1  224  220  221  222  224  32.0  34.0
# 1          2  222  220  221  223  223   NaN   NaN
# 2          3  223  221  224  224  221   NaN   NaN
# 3          4  223  221  223  223  223   NaN   NaN
# 4          5  223  221  221  223  220   NaN   NaN

# %%
dog_data_df.drop(columns=['x6','x7'],inplace=True)

# %% [markdown]
# ## analysis.

# %%
con_chart_obj =  ControlChart(dog_data_df)

# %%
con_chart_obj.create_control_chart('R')

# %%
con_chart_obj.create_control_chart('x_mean')
